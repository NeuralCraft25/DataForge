# %% [markdown]
# <a href="https://colab.research.google.com/github/NeuralCraft25/DataForge/blob/main/Prime_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re

# %%
df = pd.read_excel('/content/prime_list.xlsx')
Prime_Minister = df['Prime_Minister']
Dates_as_PM = df['Dates_as_PM']
Party = df['Party']

# %%
df['Dates_as_PM'] = df['Dates_as_PM'].astype(str)
df['Dates_as_PM'] = df['Dates_as_PM'].str.findall(r"\b\d{4}\b")
years = df['Dates_as_PM']
prime_data = df[['Dates_as_PM', 'Prime_Minister', 'Party']]
prime_data
# Out:
#      Dates_as_PM        Prime_Minister     Party
# 0             []                   NaN       NaN
# 1   [1856, 1856]          Henry Sewell       NaN
# 2   [1856, 1856]           William Fox       NaN
# 3   [1856, 1861]       Edward Stafford       NaN
# 4   [1861, 1862]           William Fox       NaN
# 5   [1862, 1863]         Alfred Domett       NaN
# 6   [1863, 1864]    Frederick Whitaker       NaN
# 7   [1864, 1865]        Frederick Weld       NaN
# 8   [1865, 1869]       Edward Stafford       NaN
# 9   [1869, 1872]           William Fox       NaN
# 10  [1872, 1872]       Edward Stafford       NaN
# 11  [1872, 1873]     George Waterhouse       NaN
# 12  [1873, 1873]           William Fox       NaN
# 13  [1873, 1875]          Julius Vogel       NaN
# 14  [1875, 1876]         Daniel Pollen       NaN
# 15  [1876, 1876]          Julius Vogel       NaN
# 16  [1876, 1877]        Harry Atkinson       NaN
# 17  [1877, 1879]           George Grey       NaN
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
prime_data.groupby('Party').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
